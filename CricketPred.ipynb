# %% [markdown]
# ### Cricket Prediction
#       Prediction  of One day Cricket Match
#
#       Data Used from website Cricsheet

# %% [markdown]
# ### Reading required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('E:\Sumayya-Donot Delete\Internship\internship2\odi.csv')

# %%
data.head()
# Out:
#    mid        date                                 venue bat_team bowl_team  \
# 0    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 1    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 2    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 3    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 4    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
#
#           batsman       bowler  runs  wickets  overs  runs_last_5  \
# 0  ME Trescothick  DT Johnston     0        0    0.1            0
# 1  ME Trescothick  DT Johnston     0        0    0.2            0
# 2  ME Trescothick  DT Johnston     4        0    0.3            4
# 3  ME Trescothick  DT Johnston     6        0    0.4            6
# 4  ME Trescothick  DT Johnston     6        0    0.5            6
#
#    wickets_last_5  striker  non-striker  total
# 0               0        0            0    301
# 1               0        0            0    301
# 2               0        0            0    301
# 3               0        0            0    301
# 4               0        0            0    301

# %% [markdown]
# ## Some Eda on data
#      1. Any null values ?
#      2. which team has taken highest score?

# %%
data.isnull().sum().sum()
data['total'].max()
data[data['total']==444]
# Out:
#          mid        date         venue bat_team bowl_team     batsman  \
# 305335  1034  2016-08-30  Trent Bridge  England  Pakistan      JJ Roy
# 305336  1034  2016-08-30  Trent Bridge  England  Pakistan      JJ Roy
# 305337  1034  2016-08-30  Trent Bridge  England  Pakistan      JJ Roy
# 305338  1034  2016-08-30  Trent Bridge  England  Pakistan      JJ Roy
# 305339  1034  2016-08-30  Trent Bridge  England  Pakistan      JJ Roy
# ...      ...         ...           ...      ...       ...         ...
# 305638  1034  2016-08-30  Trent Bridge  England  Pakistan  EJG Morgan
# 305639  1034  2016-08-30  Trent Bridge  England  Pakistan  EJG Morgan
# 305640  1034  2016-08-30  Trent Bridge  England  Pakistan  JC Buttler
# 305641  1034  2016-08-30  Trent Bridge  England  Pakistan  JC Buttler
# 305642  1034  2016-08-30  Trent Bridge  England  Pakistan  JC Buttler
#
#                bowler  runs  wickets  overs  runs_last_5  wickets_last_5  \
# 305335  Mohammad Amir     0        0    0.1            0               0
# 305336  Mohammad Amir     0        0    0.2            0               0
# 305337  Mohammad Amir     0        0    0.3            0               0
# 305338  Mohammad Amir     0        0    0.4            0               0
# 305339  Mohammad Amir     4        0    0.5            4               0
# ...               ...   ...      ...    ...          ...             ...
# 305638      Hasan Ali   439        3   49.2           57               0
# 305639      Hasan Ali   440        3   49.3           57               0
# 305640      Hasan Ali   440        3   49.4           57               0
# 305641      Hasan Ali   440        3   49.5           56               0
# 305642      Hasan Ali   444        3   49.6           59               0
#
#         striker  non-striker  total
# 305335        0            0    444
# 305336        0            0    444
# 305337        0            0    444
# 305338        0            0    444
# 305339        4            0    444
# ...         ...          ...    ...
# 305638       86           57    444
# 305639       86           57    444
# 305640       86           57    444
# 305641       86           57    444
# 305642       90           57    444
#
# [308 rows x 15 columns]

# %%
data[data['mid']==888]
# Out:
#         mid        date                          venue bat_team  bowl_team  \
# 261537  888  2014-02-28  Khan Shaheb Osman Ali Stadium    India  Sri Lanka
# 261538  888  2014-02-28  Khan Shaheb Osman Ali Stadium    India  Sri Lanka
# 261539  888  2014-02-28  Khan Shaheb Osman Ali Stadium    India  Sri Lanka
# 261540  888  2014-02-28  Khan Shaheb Osman Ali Stadium    India  Sri Lanka
# 261541  888  2014-02-28  Khan Shaheb Osman Ali Stadium    India  Sri Lanka
# ...     ...         ...                            ...      ...        ...
# 261838  888  2014-02-28  Khan Shaheb Osman Ali Stadium    India  Sri Lanka
# 261839  888  2014-02-28  Khan Shaheb Osman Ali Stadium    India  Sri Lanka
# 261840  888  2014-02-28  Khan Shaheb Osman Ali Stadium    India  Sri Lanka
# 261841  888  2014-02-28  Khan Shaheb Osman Ali Stadium    India  Sri Lanka
# 261842  888  2014-02-28  Khan Shaheb Osman Ali Stadium    India  Sri Lanka
#
#                batsman      bowler  runs  wickets  overs  runs_last_5  \
# 261537       RG Sharma  SL Malinga     0        0    0.1            0
# 261538       RG Sharma  SL Malinga     0        0    0.2            0
# 261539       RG Sharma  SL Malinga     0        0    0.3            0
# 261540       RG Sharma  SL Malinga     1        0    0.4            1
# 261541        S Dhawan  SL Malinga     1        0    0.5            1
# ...                ...         ...   ...      ...    ...          ...
# 261838  Mohammed Shami  SL Malinga   261        9   49.2           41
# 261839       RA Jadeja  SL Malinga   262        9   49.3           38
# 261840  Mohammed Shami  SL Malinga   262        9   49.4           37
# 261841  Mohammed Shami  SL Malinga   263        9   49.5           37
# 261842       RA Jadeja  SL Malinga   264        9   49.6           38
#
#         wickets_last_5  striker  non-striker  total
# 261537               0        0            0    264
# 261538               0        0            0    264
# 261539               0        0            0    264
# 261540               0        1            0    264
# 261541               0        1            0    264
# ...                ...      ...          ...    ...
# 261838               2       20           13    264
# 261839               2       21           13    264
# 261840               2       21           13    264
# 261841               2       21           14    264
# 261842               2       22           14    264
#
# [306 rows x 15 columns]

# %% [markdown]
# ### Features used
#        Runs
#        Wicket
#        Over
#        Striker
#        Non Striker
#
# ### Label
#        Total

# %%
X=data.iloc[:,[7,8,9,12,13]].values #runs,wicket,over,striker,non striker
y=data.iloc[:,14].values #runs

# %% [markdown]
# ## Splitting data into train and test Model

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
X_test
# Out:
# array([[58. ,  6. , 20.2, 22. ,  0. ],
#        [81. ,  5. , 23.5, 29. , 14. ],
#        [19. ,  0. ,  5.5, 13. ,  2. ],
#        ...,
#        [80. ,  0. , 10.3, 39. , 38. ],
#        [ 5. ,  0. ,  0.3,  0. ,  0. ],
#        [13. ,  0. ,  4.2,  7. ,  6. ]])

# %% [markdown]
# ### Scaling data before applying ML algorithms

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Prediction using Linear Regreesion

# %%
from sklearn.linear_model import LinearRegression
lin=LinearRegression()
lin.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Checking the goodness of model using R2 value

# %%
y_pred=lin.predict(X_test)
score=lin.score(X_test,y_test)*100
print("R-squared value:" , score)
y_pred
# Out:
# R-squared value: 52.737657811129445
# array([164.08674918, 192.56966018, 255.74830646, ..., 308.90763905,
#        258.37939597, 253.98483871])

# %% [markdown]
# ### Prediction using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
lin = RandomForestRegressor(n_estimators=100,max_features=None)
lin.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features=None, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# ### checking goodness of model using R2 and we got a better accuracy with random Forest

# %%
y_pred=lin.predict(X_test)
score=lin.score(X_test,y_test)*100
print("R-squared value:" , score)
y_pred
# Out:
# R-squared value: 79.5323792837045
# array([124.03      , 215.92      , 254.06      , ..., 306.52      ,
#        226.57192166, 293.97105952])

# %% [markdown]
# ### checking with random inputs to check fitness

# %%
import numpy as np
new_prediction = lin.predict(sc.transform(np.array([[80,0,13,50,50]])))
print("Prediction score:" , new_prediction)
# Out:
# Prediction score: [329.53666667]
